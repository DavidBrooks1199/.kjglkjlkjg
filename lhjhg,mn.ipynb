# %%
from IPython.core.display import SVG
SVG(filename='Airport ER diagram revised.svg')

# %% [markdown]
# from IPython.core.display import SVG
# SVG(filename='Airport ER diagram revised.svg')
